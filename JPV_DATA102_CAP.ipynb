# %% [markdown]
# <a href="https://colab.research.google.com/github/RedPandaStyle/ACE-DATA201/blob/main/JPV_DATA102_CAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import public data to local terminal and load into notebook
v = pd.read_csv('Motor_Vehicle_Collisions_-_Crashes.csv')
v
# Out:
#         CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0       07/20/2022       1:25       NaN       NaN  40.835808 -73.890830
# 1       07/21/2022       5:20       NaN       NaN        NaN        NaN
# 2       04/14/2021       5:32       NaN       NaN        NaN        NaN
# 3       04/13/2021      21:35  BROOKLYN   11217.0  40.683580 -73.976170
# 4       04/15/2021      16:15       NaN       NaN        NaN        NaN
# ...            ...        ...       ...       ...        ...        ...
# 590844  08/16/2018      15:15       NaN       NaN  40.709145 -73.727640
# 590845  08/07/2018       0:00    QUEENS   11420.0  40.677654 -73.828660
# 590846  08/12/2018      12:40    QUEENS   11429.0  40.711000 -73.746140
# 590847  08/12/2018      18:40    QUEENS   11413.0  40.671684 -73.756470
# 590848  08/13/2018      10:30  BROOKLYN   11211.0  40.713820 -73.937706
#
#                       LOCATION                    ON STREET NAME  \
# ...

# %%
v.shape
# Out:
# (590849, 29)

# %%
v.dtypes
# Out:
# CRASH DATE                        object
# CRASH TIME                        object
# BOROUGH                           object
# ZIP CODE                         float64
# LATITUDE                         float64
# LONGITUDE                        float64
# LOCATION                          object
# ON STREET NAME                    object
# CROSS STREET NAME                 object
# OFF STREET NAME                   object
# NUMBER OF PERSONS INJURED        float64
# NUMBER OF PERSONS KILLED         float64
# NUMBER OF PEDESTRIANS INJURED      int64
# NUMBER OF PEDESTRIANS KILLED       int64
# NUMBER OF CYCLIST INJURED          int64
# NUMBER OF CYCLIST KILLED           int64
# NUMBER OF MOTORIST INJURED         int64
# NUMBER OF MOTORIST KILLED          int64
# CONTRIBUTING FACTOR VEHICLE 1     object
# CONTRIBUTING FACTOR VEHICLE 2     object
# CONTRIBUTING FACTOR VEHICLE 3     object
# CONTRIBUTING FACTOR VEHICLE 4     object
# CONTRIBUTING FACTOR VEHICLE 5     object
# ...

# %%
#List columns...
v.columns
print(*v, sep = '\n')
# Out:
# CRASH DATE
# CRASH TIME
# BOROUGH
# ZIP CODE
# LATITUDE
# LONGITUDE
# LOCATION
# ON STREET NAME
# CROSS STREET NAME
# OFF STREET NAME
# NUMBER OF PERSONS INJURED
# NUMBER OF PERSONS KILLED
# NUMBER OF PEDESTRIANS INJURED
# NUMBER OF PEDESTRIANS KILLED
# NUMBER OF CYCLIST INJURED
# NUMBER OF CYCLIST KILLED
# NUMBER OF MOTORIST INJURED
# NUMBER OF MOTORIST KILLED
# CONTRIBUTING FACTOR VEHICLE 1
# CONTRIBUTING FACTOR VEHICLE 2
# CONTRIBUTING FACTOR VEHICLE 3
# CONTRIBUTING FACTOR VEHICLE 4
# CONTRIBUTING FACTOR VEHICLE 5
# COLLISION_ID
# VEHICLE TYPE CODE 1
# VEHICLE TYPE CODE 2
# VEHICLE TYPE CODE 3
# VEHICLE TYPE CODE 4
# VEHICLE TYPE CODE 5

# %%
#Drop data that isn't being looked at to decrease resource consumption
v1 = v.drop(['CONTRIBUTING FACTOR VEHICLE 1',
'CONTRIBUTING FACTOR VEHICLE 2',
'CONTRIBUTING FACTOR VEHICLE 3',
'CONTRIBUTING FACTOR VEHICLE 4',
'CONTRIBUTING FACTOR VEHICLE 5',
'COLLISION_ID',
'VEHICLE TYPE CODE 2',
'VEHICLE TYPE CODE 3',
'VEHICLE TYPE CODE 4',
'VEHICLE TYPE CODE 5'], axis=1)
v1
# Out:
#         CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0       07/20/2022       1:25       NaN       NaN  40.835808 -73.890830
# 1       07/21/2022       5:20       NaN       NaN        NaN        NaN
# 2       04/14/2021       5:32       NaN       NaN        NaN        NaN
# 3       04/13/2021      21:35  BROOKLYN   11217.0  40.683580 -73.976170
# 4       04/15/2021      16:15       NaN       NaN        NaN        NaN
# ...            ...        ...       ...       ...        ...        ...
# 590844  08/16/2018      15:15       NaN       NaN  40.709145 -73.727640
# 590845  08/07/2018       0:00    QUEENS   11420.0  40.677654 -73.828660
# 590846  08/12/2018      12:40    QUEENS   11429.0  40.711000 -73.746140
# 590847  08/12/2018      18:40    QUEENS   11413.0  40.671684 -73.756470
# 590848  08/13/2018      10:30  BROOKLYN   11211.0  40.713820 -73.937706
#
#                       LOCATION                    ON STREET NAME  \
# ...

# %%
#Hone in on Queens and have the count as a check for when you filter later on.
v1.value_counts('BOROUGH')
# Out:
# BOROUGH
# BROOKLYN         128167
# QUEENS           107884
# MANHATTAN         68593
# BRONX             66847
# STATEN ISLAND     12845
# dtype: int64

# %%
#Drop null values for Borough
v1= v1.dropna(subset=['BOROUGH'])
v1
# Out:
#         CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 3       04/13/2021      21:35   BROOKLYN   11217.0  40.683580 -73.976170
# 7       04/13/2021      16:00   BROOKLYN   11222.0        NaN        NaN
# 12      04/13/2021      17:30     QUEENS   11106.0        NaN        NaN
# 17      04/11/2021      21:06   BROOKLYN   11226.0        NaN        NaN
# 18      07/19/2022      16:12  MANHATTAN   10018.0        NaN        NaN
# ...            ...        ...        ...       ...        ...        ...
# 590843  08/13/2018      10:12     QUEENS   11101.0  40.745235 -73.937706
# 590845  08/07/2018       0:00     QUEENS   11420.0  40.677654 -73.828660
# 590846  08/12/2018      12:40     QUEENS   11429.0  40.711000 -73.746140
# 590847  08/12/2018      18:40     QUEENS   11413.0  40.671684 -73.756470
# 590848  08/13/2018      10:30   BROOKLYN   11211.0  40.713820 -73.937706
#
#                        LOCATION                    ON STREET NAME  \
# ...

# %%
#Filter for Queens, Count checks out at 353789. 
#No pertinent data has been lost in filtering.
v1 = v1[v1['BOROUGH'].str.contains('QUEENS')]
v1
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 12      04/13/2021      17:30  QUEENS   11106.0        NaN        NaN
# 32      04/14/2021      21:43  QUEENS   11429.0  40.714020 -73.748270
# 40      04/15/2021      14:30  QUEENS   11377.0  40.751840 -73.903580
# 61      04/16/2021      11:00  QUEENS   11368.0  40.749580 -73.865410
# 62      04/16/2021      17:00  QUEENS   11366.0  40.731970 -73.786510
# ...            ...        ...     ...       ...        ...        ...
# 590839  08/19/2018       2:05  QUEENS   11385.0  40.704266 -73.891850
# 590843  08/13/2018      10:12  QUEENS   11101.0  40.745235 -73.937706
# 590845  08/07/2018       0:00  QUEENS   11420.0  40.677654 -73.828660
# 590846  08/12/2018      12:40  QUEENS   11429.0  40.711000 -73.746140
# 590847  08/12/2018      18:40  QUEENS   11413.0  40.671684 -73.756470
#
#                        LOCATION                    ON STREET NAME  \
# ...

# %%
#Trying to filter by year becomes difficult because the format
#is not in a standard date/time value.

pd.to_datetime('1970-01-01').value
v1.value_counts('CRASH DATE')
# Out:
# CRASH DATE
# 11/15/2018    214
# 01/18/2020    183
# 06/26/2019    169
# 05/21/2019    165
# 12/18/2018    163
#              ...
# 04/10/2016      1
# 03/20/2016      1
# 04/13/2016      1
# 04/11/2016      1
# 03/18/2016      1
# Length: 1470, dtype: int64

# %%
# 2 years before vision zero
v12 = v1[v1['CRASH DATE'].str.contains('2012')]
v12
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 157380  09/25/2012      12:36  QUEENS   11385.0  40.700005  -73.90296
#
#                       LOCATION    ON STREET NAME CROSS STREET NAME  \
# 157380  (40.700005, -73.90296)  WEIRFIELD STREET     SENECA AVENUE
#
#        OFF STREET NAME  NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 157380             NaN                        0.0                       0.0
#
#         NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# 157380                              0                             0
#
#         NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# 157380                          0                         0
#
#         NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED  \
# 157380                           0                          0
#
#                         VEHICLE TYPE CODE 1
# 157380  Station Wagon/Sport Utility Vehicle

# %%
v12pi = v12[v12['NUMBER OF PEDESTRIANS INJURED'] >= 1]
v12pi
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, VEHICLE TYPE CODE 1]
# Index: []

# %%
v12pk = v12[v12['NUMBER OF PEDESTRIANS KILLED'] >=1]
v12pk
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, VEHICLE TYPE CODE 1]
# Index: []

# %%
# 1 Year before Vision Zero
v13 = v1[v1['CRASH DATE'].str.contains('2013')]
v13
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, VEHICLE TYPE CODE 1]
# Index: []

# %%
v13pi = v13[v13['NUMBER OF PEDESTRIANS INJURED'] >= 1]
v13pi
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, VEHICLE TYPE CODE 1]
# Index: []

# %%
v13pk = v13[v13['NUMBER OF PEDESTRIANS KILLED'] >= 1]
v13pk
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, VEHICLE TYPE CODE 1]
# Index: []

# %%
v14 = v1[v1['CRASH DATE'].str.contains('2014')]
v14
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, VEHICLE TYPE CODE 1]
# Index: []

# %%
v14pi = v14[v14['NUMBER OF PEDESTRIANS INJURED'] >= 1]
v14pi
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, VEHICLE TYPE CODE 1]
# Index: []

# %%
v14pk = v14[v14['NUMBER OF PEDESTRIANS KILLED'] >= 1]
v14pk
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, VEHICLE TYPE CODE 1]
# Index: []

# %%
v15 = v1[v1['CRASH DATE'].str.contains('2015')]
v15
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, VEHICLE TYPE CODE 1]
# Index: []

# %%
v15pi = v15[v15['NUMBER OF PEDESTRIANS INJURED'] >= 1]
v15pi
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, VEHICLE TYPE CODE 1]
# Index: []

# %%
v15pk = v15[v15['NUMBER OF PEDESTRIANS KILLED'] >= 1]
v15pk
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, VEHICLE TYPE CODE 1]
# Index: []

# %%
v16 = v1[v1['CRASH DATE'].str.contains('2016')]
v16
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE  LATITUDE  LONGITUDE LOCATION  \
# 75014   04/23/2016      10:05  QUEENS   11694.0       NaN        NaN      NaN
# 75956   04/13/2016       0:00  QUEENS   11694.0       NaN        NaN      NaN
# 81961   04/15/2016       7:40  QUEENS   11385.0       NaN        NaN      NaN
# 122223  03/18/2016      13:15  QUEENS   11433.0       NaN        NaN      NaN
# 130402  03/20/2016      19:30  QUEENS   11411.0       NaN        NaN      NaN
# 130590  03/30/2016      23:00  QUEENS   11374.0       NaN        NaN      NaN
# 135262  04/10/2016      23:40  QUEENS   11411.0       NaN        NaN      NaN
# 137137  04/08/2016      18:15  QUEENS   11691.0       NaN        NaN      NaN
# 138022  04/07/2016      18:00  QUEENS   11379.0       NaN        NaN      NaN
# 138344  03/26/2016      13:08  QUEENS   11691.0       NaN        NaN      NaN
# 140672  04/11/2016      20:05  QUEENS   11355.0       NaN        NaN      NaN
#
# ...

# %%
v16pi = v16[v16['NUMBER OF PEDESTRIANS INJURED'] >= 1]
v16pi
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, VEHICLE TYPE CODE 1]
# Index: []

# %%
v16pk = v16[v16['NUMBER OF PEDESTRIANS KILLED'] >= 1]
v16pk
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, VEHICLE TYPE CODE 1]
# Index: []

# %%
v17 = v1[v1['CRASH DATE'].str.contains('2017')]
v17
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, VEHICLE TYPE CODE 1]
# Index: []

# %%
v17pi = v17[v17['NUMBER OF PEDESTRIANS INJURED'] >= 1]
v17pi
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, VEHICLE TYPE CODE 1]
# Index: []

# %%
v17pk = v17[v17['NUMBER OF PEDESTRIANS KILLED'] >= 1]
v17pk
# Out:
# Empty DataFrame
# Columns: [CRASH DATE, CRASH TIME, BOROUGH, ZIP CODE, LATITUDE, LONGITUDE, LOCATION, ON STREET NAME, CROSS STREET NAME, OFF STREET NAME, NUMBER OF PERSONS INJURED, NUMBER OF PERSONS KILLED, NUMBER OF PEDESTRIANS INJURED, NUMBER OF PEDESTRIANS KILLED, NUMBER OF CYCLIST INJURED, NUMBER OF CYCLIST KILLED, NUMBER OF MOTORIST INJURED, NUMBER OF MOTORIST KILLED, VEHICLE TYPE CODE 1]
# Index: []

# %%
v18 = v1[v1['CRASH DATE'].str.contains('2018')]
v18
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 492422  12/12/2018       9:32  QUEENS   11104.0        NaN        NaN
# 493690  12/24/2018       9:26  QUEENS   11378.0        NaN        NaN
# 493703  12/18/2018      13:45  QUEENS   11364.0        NaN        NaN
# 493728  12/09/2018      23:36  QUEENS   11367.0        NaN        NaN
# 493748  12/02/2018      17:30  QUEENS   11369.0        NaN        NaN
# ...            ...        ...     ...       ...        ...        ...
# 590839  08/19/2018       2:05  QUEENS   11385.0  40.704266 -73.891850
# 590843  08/13/2018      10:12  QUEENS   11101.0  40.745235 -73.937706
# 590845  08/07/2018       0:00  QUEENS   11420.0  40.677654 -73.828660
# 590846  08/12/2018      12:40  QUEENS   11429.0  40.711000 -73.746140
# 590847  08/12/2018      18:40  QUEENS   11413.0  40.671684 -73.756470
#
#                        LOCATION                    ON STREET NAME  \
# 492422                      NaN  48th St
# ...

# %%
v18pi = v18[v18['NUMBER OF PEDESTRIANS INJURED'] >= 1]
v18pi
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 493703  12/18/2018      13:45  QUEENS   11364.0        NaN        NaN
# 493977  12/10/2018      17:30  QUEENS   11435.0  40.702477 -73.812860
# 494088  12/19/2018       9:55  QUEENS   11357.0  40.788525 -73.811170
# 494130  12/13/2018       6:20  QUEENS   11377.0  40.750160 -73.904340
# 494131  12/14/2018       6:45  QUEENS   11420.0  40.675766 -73.816850
# ...            ...        ...     ...       ...        ...        ...
# 590384  08/04/2018      16:40  QUEENS   11374.0  40.726920 -73.861770
# 590425  08/11/2018      18:00  QUEENS   11377.0  40.752210 -73.904430
# 590436  08/03/2018      15:36  QUEENS   11103.0  40.756676 -73.920876
# 590480  08/10/2018      20:15  QUEENS   11417.0  40.672146 -73.843180
# 590761  08/21/2018      13:20  QUEENS   11414.0  40.664295 -73.839380
#
#                        LOCATION                    ON STREET NAME  \
# 493703                      NaN  73th Avenue
# ...

# %%
v18pk = v18[v18['NUMBER OF PEDESTRIANS KILLED'] >= 1]
v18pk
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 498608  12/31/2018      12:44  QUEENS   11372.0  40.749653 -73.885250
# 505465  12/18/2018      16:01  QUEENS   11414.0  40.659172 -73.839874
# 507890  12/17/2018       6:20  QUEENS   11373.0  40.734768 -73.874590
# 516121  11/28/2018      18:02  QUEENS   11429.0  40.703712 -73.749600
# 525966  11/03/2018      14:34  QUEENS   11354.0  40.769096 -73.833664
# 528582  11/07/2018       6:33  QUEENS   11418.0  40.701530 -73.823410
# 530662  11/11/2018      17:33  QUEENS   11375.0  40.717160 -73.846695
# 535416  11/08/2018      16:09  QUEENS   11366.0  40.726036 -73.790855
# 537775  11/05/2018      14:40  QUEENS   11367.0  40.731777 -73.817535
# 555421  09/25/2018       7:15  QUEENS   11434.0  40.690685 -73.781610
# 568936  09/16/2018       8:37  QUEENS   11354.0  40.769283 -73.824450
# 571167  09/20/2018       5:51  QUEENS   11421.0  40.693660 -73.852170
# ...

# %%
#Pre-CVD-19 shows 39865 incidents
v19 = v1[v1['CRASH DATE'].str.contains('2019')]
v19
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 169806  12/31/2019      11:30  QUEENS   11378.0        NaN        NaN
# 170593  12/28/2019      20:20  QUEENS   11432.0        NaN        NaN
# 170694  12/27/2019      13:03  QUEENS   11378.0        NaN        NaN
# 171767  12/23/2019      15:40  QUEENS   11374.0        NaN        NaN
# 173187  12/19/2019      21:00  QUEENS   11692.0        NaN        NaN
# ...            ...        ...     ...       ...        ...        ...
# 509380  01/01/2019      11:00  QUEENS   11385.0  40.698704  -73.89974
# 509383  01/01/2019      12:30  QUEENS   11368.0  40.741140  -73.85747
# 509467  01/01/2019       2:18  QUEENS   11375.0  40.716507  -73.84711
# 509468  01/01/2019      13:00  QUEENS   11413.0  40.665497  -73.75573
# 509536  01/01/2019      10:23  QUEENS   11369.0  40.758680  -73.87552
#
#                       LOCATION                    ON STREET NAME  \
# 169806                     NaN  QUEENS MIDTOWN EXPRESSWAY
# ...

# %%
v19pi = v19[v19['NUMBER OF PEDESTRIANS INJURED'] >= 1]
v19pi
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 207656  12/16/2019      18:45  QUEENS   11428.0  40.720550 -73.732070
# 207838  12/29/2019      19:56  QUEENS   11355.0  40.759686 -73.821175
# 208151  12/20/2019       6:54  QUEENS   11375.0  40.725628 -73.845850
# 208166  12/29/2019      16:47  QUEENS   11355.0  40.753720 -73.832830
# 208223  12/30/2019      17:07  QUEENS   11421.0  40.689842 -73.850075
# ...            ...        ...     ...       ...        ...        ...
# 493658  01/04/2019      17:35  QUEENS   11357.0  40.778164 -73.801180
# 493664  01/04/2019      20:26  QUEENS   11432.0  40.713173 -73.785730
# 494263  01/01/2019      19:30  QUEENS   11427.0  40.728024 -73.747640
# 497501  01/01/2019      20:30  QUEENS   11354.0  40.764988 -73.820670
# 508115  01/02/2019       9:15  QUEENS   11354.0  40.761547 -73.831130
#
#                        LOCATION                    ON STREET NAME  \
# ...

# %%
v19pk = v19[v19['NUMBER OF PEDESTRIANS KILLED'] >= 1]
v19pk
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 220255  12/18/2019       8:35  QUEENS   11355.0  40.755905 -73.830440
# 223891  12/11/2019      15:17  QUEENS   11385.0  40.704155 -73.907520
# 256101  12/11/2019      20:18  QUEENS   11377.0  40.751190 -73.902030
# 259804  12/09/2019      16:57  QUEENS   11385.0  40.709866 -73.911190
# 263527  11/30/2019      17:41  QUEENS   11004.0  40.744860 -73.711120
# 264979  11/29/2019       8:45  QUEENS   11377.0  40.746048 -73.899030
# 265613  11/22/2019      12:35  QUEENS   11354.0  40.763150 -73.812610
# 272714  11/05/2019      21:15  QUEENS   11435.0  40.700580 -73.807750
# 273643  11/06/2019       8:37  QUEENS   11379.0  40.711160 -73.879074
# 276667  10/27/2019       7:03  QUEENS   11369.0  40.763180 -73.876335
# 288896  09/21/2019      21:13  QUEENS   11367.0  40.729443 -73.825510
# 331541  08/17/2019      12:10  QUEENS   11378.0  40.714024 -73.902374
# ...

# %%
#Filter by years. CVD-19 shows a marked drop 
v20 = v1[v1['CRASH DATE'].str.contains('2020')]
v20
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 6655    05/02/2020      17:30  QUEENS   11436.0  40.673760 -73.794730
# 18042   12/16/2020      16:20  QUEENS   11428.0  40.713900 -73.753900
# 19215   06/04/2020       7:30  QUEENS   11368.0  40.744232 -73.861275
# 19979   12/03/2020      15:10  QUEENS   11375.0        NaN        NaN
# 21637   12/19/2020      16:15  QUEENS   11378.0  40.723620 -73.888020
# ...            ...        ...     ...       ...        ...        ...
# 223576  01/10/2020      19:00  QUEENS   11420.0  40.686650 -73.809180
# 223579  01/09/2020      21:21  QUEENS   11385.0  40.712200 -73.862080
# 223598  01/14/2020      14:30  QUEENS   11385.0  40.710420 -73.859640
# 308332  10/04/2020      23:20  QUEENS   11421.0  40.687340 -73.861046
# 384812  06/20/2020       7:50  QUEENS   11354.0  40.757020 -73.838680
#
#                        LOCATION                    ON STREET NAME  \
# ...

# %%
v20pi = v20[v20['NUMBER OF PEDESTRIANS INJURED'] >= 1]
v20pi
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 21637   12/19/2020      16:15  QUEENS   11378.0  40.723620  -73.88802
# 44514   12/15/2020      17:30  QUEENS   11379.0  40.712350  -73.89129
# 44818   12/31/2020      15:12  QUEENS   11385.0  40.701070  -73.89116
# 45170   12/21/2020      11:05  QUEENS   11433.0  40.704033  -73.79380
# 45312   12/16/2020      18:00  QUEENS   11355.0  40.751453  -73.83228
# ...            ...        ...     ...       ...        ...        ...
# 223068  01/14/2020      17:47  QUEENS   11369.0  40.761990  -73.86934
# 223196  01/16/2020       8:45  QUEENS   11370.0  40.759230  -73.88604
# 223199  01/07/2020       6:52  QUEENS   11368.0  40.737160  -73.86405
# 223444  01/07/2020      19:00  QUEENS   11434.0  40.666840  -73.78941
# 223491  01/02/2020      13:40  QUEENS   11372.0  40.747630  -73.88394
#
#                       LOCATION                    ON STREET NAME  \
# 21637    (40.72362, -73.88802)  72 STREET
# ...

# %%
v20pk = v20[v20['NUMBER OF PEDESTRIANS KILLED'] >= 1]
v20pk
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 60567   10/30/2020      17:18  QUEENS   11432.0  40.705147 -73.795700
# 110168  08/27/2020       8:16  QUEENS   11385.0  40.704200 -73.882880
# 111933  09/06/2020      13:30  QUEENS   11354.0  40.761547 -73.831130
# 112096  10/10/2020      23:36  QUEENS   11433.0  40.688435 -73.787650
# 113256  09/19/2020      21:08  QUEENS   11355.0  40.752316 -73.832400
# 117137  09/01/2020      19:46  QUEENS   11423.0  40.713497 -73.758220
# 118191  09/04/2020       9:51  QUEENS   11377.0  40.745110 -73.908640
# 120775  08/08/2020       5:15  QUEENS   11354.0  40.765137 -73.819440
# 129734  08/15/2020      23:59  QUEENS   11435.0  40.693295 -73.808020
# 135526  07/07/2020       9:10  QUEENS   11691.0  40.599510 -73.749794
# 148399  05/18/2020       5:18  QUEENS   11415.0  40.704857 -73.827286
# 149484  06/04/2020       3:55  QUEENS   11420.0  40.667667 -73.807150
# ...

# %%
#During CVD-19 and also seeing the effects of vision zero
v21 = v1[v1['CRASH DATE'].str.contains('2021')]
v21
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 12      04/13/2021      17:30  QUEENS   11106.0        NaN        NaN
# 32      04/14/2021      21:43  QUEENS   11429.0  40.714020  -73.74827
# 40      04/15/2021      14:30  QUEENS   11377.0  40.751840  -73.90358
# 61      04/16/2021      11:00  QUEENS   11368.0  40.749580  -73.86541
# 62      04/16/2021      17:00  QUEENS   11366.0  40.731970  -73.78651
# ...            ...        ...     ...       ...        ...        ...
# 310847  12/02/2021      23:30  QUEENS   11372.0  40.756080  -73.88050
# 311589  12/18/2021      11:29  QUEENS   11368.0  40.753147  -73.86339
# 313311  08/09/2021      18:41  QUEENS   11370.0  40.773808  -73.89290
# 316672  12/23/2021       0:20  QUEENS   11369.0  40.765460  -73.88149
# 319201  11/20/2021      17:21  QUEENS   11373.0  40.733498  -73.87038
#
#                       LOCATION    ON STREET NAME CROSS STREET NAME  \
# ...

# %%
v21pi = v21[v21['NUMBER OF PEDESTRIANS INJURED'] >= 1]
v21pi
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 76      04/16/2021       8:40  QUEENS   11379.0  40.727913 -73.873245
# 138     04/14/2021       9:05  QUEENS   11432.0        NaN        NaN
# 150     04/15/2021      10:30  QUEENS   11420.0  40.680496 -73.821365
# 322     04/14/2021      11:46  QUEENS   11385.0  40.703260 -73.864740
# 342     04/12/2021      20:00  QUEENS   11357.0  40.781715 -73.823845
# ...            ...        ...     ...       ...        ...        ...
# 239673  12/02/2021      17:15  QUEENS   11435.0  40.702530 -73.814300
# 240419  12/11/2021      19:10  QUEENS   11369.0  40.761590 -73.871216
# 241267  12/03/2021      14:40  QUEENS   11373.0  40.744907 -73.889160
# 242856  09/26/2021       1:36  QUEENS   11101.0  40.752693 -73.932915
# 248201  12/21/2021      15:56  QUEENS   11377.0  40.746334 -73.896330
#
#                        LOCATION  ON STREET NAME   CROSS STREET NAME  \
# ...

# %%
v21pk = v21[v21['NUMBER OF PEDESTRIANS KILLED'] >= 1]
v21pk
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 15682   05/23/2021      15:21  QUEENS   11361.0        NaN        NaN
# 16719   05/24/2021       0:27  QUEENS   11417.0  40.680687 -73.844590
# 17791   05/28/2021      13:15  QUEENS   11373.0  40.743310 -73.874510
# 18412   05/28/2021      20:39  QUEENS   11105.0  40.777958 -73.908470
# 29675   03/12/2021      13:40  QUEENS   11435.0  40.708870 -73.818710
# 31940   02/15/2021      13:56  QUEENS   11417.0  40.673325 -73.843260
# 34121   03/22/2021      22:05  QUEENS   11412.0  40.696120 -73.746190
# 42076   03/04/2021      22:04  QUEENS   11414.0        NaN        NaN
# 51947   01/29/2021      20:21  QUEENS   11430.0        NaN        NaN
# 84919   07/18/2021       2:39  QUEENS   11385.0  40.703434 -73.911810
# 89562   08/03/2021      12:39  QUEENS   11379.0  40.721650 -73.886444
# 101487  07/16/2021       8:00  QUEENS   11365.0  40.741623 -73.791090
# ...

# %%
#Adding up all the DataFrames we get 353789
v22 = v1[v1['CRASH DATE'].str.contains('2022')]
v22
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 768     07/07/2022      20:29  QUEENS   11378.0  40.729633 -73.895630
# 771     07/20/2022      13:00  QUEENS   11419.0  40.684020 -73.823080
# 777     07/21/2022       6:39  QUEENS   11105.0  40.776962 -73.902400
# 783     07/12/2022       4:01  QUEENS   11372.0  40.754387 -73.896530
# 785     07/20/2022       9:52  QUEENS   11691.0  40.600754 -73.739730
# ...            ...        ...     ...       ...        ...        ...
# 393777  07/19/2022      13:00  QUEENS   11373.0  40.740402 -73.882130
# 393783  07/19/2022      14:30  QUEENS   11364.0  40.735280 -73.749344
# 393786  07/19/2022      11:40  QUEENS   11105.0  40.769558 -73.906075
# 393788  07/19/2022      14:40  QUEENS   11434.0  40.679028 -73.789100
# 393792  07/19/2022      16:25  QUEENS   11354.0  40.770410 -73.824680
#
#                        LOCATION         ON STREET NAME   CROSS STREET NAME  \
# ...

# %%
v22pi = v22[v22['NUMBER OF PEDESTRIANS INJURED'] >= 1]
v22pi
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 833     07/20/2022      14:45  QUEENS   11375.0  40.715570 -73.829840
# 924     07/22/2022      12:28  QUEENS   11691.0  40.603420 -73.753060
# 1315    07/14/2022      21:00  QUEENS   11103.0  40.762012 -73.911000
# 1347    07/22/2022       6:20  QUEENS   11421.0  40.693660 -73.852170
# 1457    07/21/2022      12:02  QUEENS   11368.0  40.737335 -73.863450
# ...            ...        ...     ...       ...        ...        ...
# 393353  07/18/2022      18:25  QUEENS   11355.0  40.753307 -73.827385
# 393693  07/18/2022       8:53  QUEENS   11105.0  40.771600 -73.908960
# 393706  07/19/2022      19:20  QUEENS   11422.0  40.657360 -73.741540
# 393745  07/14/2022      19:40  QUEENS   11101.0  40.753030 -73.921630
# 393761  07/16/2022      18:15  QUEENS   11106.0  40.766064 -73.930890
#
#                        LOCATION         ON STREET NAME    CROSS STREET NAME  \
# ...

# %%
v22pk = v22[v22['NUMBER OF PEDESTRIANS KILLED'] >= 1]
v22pk
# Out:
#         CRASH DATE CRASH TIME BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 243965  01/24/2022      10:28  QUEENS   11358.0  40.758785 -73.790470
# 301297  02/24/2022       9:50  QUEENS   11423.0  40.730194 -73.777580
# 306699  03/15/2022      15:35  QUEENS   11364.0  40.740723 -73.757164
# 307787  03/11/2022      21:25  QUEENS   11354.0  40.765137 -73.819440
# 379260  06/02/2022      21:20  QUEENS   11377.0  40.748993 -73.896870
# 385596  06/21/2022      18:54  QUEENS   11378.0  40.728520 -73.905730
#
#                        LOCATION      ON STREET NAME CROSS STREET NAME  \
# 243965   (40.758785, -73.79047)                 NaN               NaN
# 301297   (40.730194, -73.77758)      UNION TURNPIKE        193 STREET
# 306699  (40.740723, -73.757164)                 NaN               NaN
# 307787   (40.765137, -73.81944)  NORTHERN BOULEVARD        147 STREET
# 379260   (40.748993, -73.89687)           69 STREET          BROADWAY
# ...
